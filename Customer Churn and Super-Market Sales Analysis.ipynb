# %% [markdown]
# # SetUp

# %%
import sys
assert sys.version_info>=(3,7)
import pandas as pd

# %%
from packaging import version
import sklearn
assert version.parse(sklearn.__version__)>= version.parse("1.0.1")

# %%
import matplotlib.pyplot as plt
plt.rc('font',size=14)
plt.rc('axes',labelsize=14,titlesize=14)
plt.rc('legend',fontsize=14)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)

# %%
from pathlib import Path
IMAGES_PATH= Path() / "images" / "ensembles"
IMAGES_PATH.mkdir(parents=True,exist_ok=True)
def save_fig(fig_id,tight_layout=True,fig_extension="png",resolution=300):
    path=IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension,dpi=resolution)

# %% [markdown]
# # Task 1: Customer Churn

# %% [markdown]
# # Description of the data set:
#     The customer churn dataset dataset captures customer interactions with an online retail store.
#     There are 15 atttributes in the data . Some of them are categorical and some of the are numerical
#     attributes.Using these attributes we have built two classifier, to predict wheather a customer will churn
#     or not with a particular business. So clearly we have used the churn attribute as the target variable and all
#     other attributes as Input attributes(or variable).

# %% [markdown]
# ## The data set

# %%
data1 = pd.read_csv("customer-churn-data.csv") 
data1
# Out:
#      CustomerID  Age  Gender  AnnualIncome  TotalSpend  YearsAsCustomer  \
# 0             1   62   Other         45.15     5892.58                5
# 1             2   65    Male         79.51     9025.47               13
# 2             3   18    Male         29.19      618.83               13
# 3             4   21   Other         79.63     9110.30                3
# 4             5   21   Other         77.66     5390.88               15
# ..          ...  ...     ...           ...         ...              ...
# 995         996   54    Male        143.72     1089.09                2
# 996         997   19    Male        164.19     3700.24                9
# 997         998   47  Female        113.31      705.85               17
# 998         999   23    Male         72.98     3891.60                7
# 999        1000   34   Other        134.86     3956.71               15
#
#      NumOfPurchases  AvgTransactionAmount  NumOfReturns  NumOfSupportQueries  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder      

data1 = pd.read_csv("customer-churn-data.csv")     
data1=data1.drop(columns=["CustomerID"]) 
categorical_cols = ["Gender", "EmailOptIn", "PromotionResponse"]

label_encoder = LabelEncoder()
for col in categorical_cols:
    data1[col] = label_encoder.fit_transform(data1[col])

# %% [raw]
# Here , in the above curnel we have done the preprocessing of the data set.
# At first we have identified one unnecessary column to build the model, namely
# the column "CustomerID" , which is an unique identifier of every customer, so the
# impurity gain ratio will be too much less if we use this column and also there
# is a danger of overfitting if we use this column while building our model.
# So , we have dropped the column. After that we have done labelencoding of the categorical
# columns. In the label encoding process using the label encoder, we convert every categorical
# columns into numerical columns.
# we have converted the "Gender", "EmailOptIn", and "PromotionResponse" columns(which are categorical columns)
# into numerical columns(Note that we have not converted the "Churn" column into a numerical column , as we will
# use it as a target variable").

# %% [markdown]
# ### modified data1

# %%
data1
# Out:
#      Age  Gender  AnnualIncome  TotalSpend  YearsAsCustomer  NumOfPurchases  \
# 0     62       2         45.15     5892.58                5              22
# 1     65       1         79.51     9025.47               13              77
# 2     18       1         29.19      618.83               13              71
# 3     21       2         79.63     9110.30                3              33
# 4     21       2         77.66     5390.88               15              43
# ..   ...     ...           ...         ...              ...             ...
# 995   54       1        143.72     1089.09                2              29
# 996   19       1        164.19     3700.24                9              90
# 997   47       0        113.31      705.85               17              69
# 998   23       1         72.98     3891.60                7              31
# 999   34       2        134.86     3956.71               15              48
#
# ...

# %%
from sklearn.model_selection import train_test_split
X1=data1.drop(columns=['Churn'])
y1=data1['Churn']
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.2,random_state=42)

# %% [raw]
# used all the columns as input features but the column "churn" which we have used as a target feature
# we have spllited the data set into input(X1) and ouput(y1) features and used the train_test_split function to
# partition the data set into tarining and the test data, we have selected randomly 80 percent of the data as
# the training data and the remaining 20 percent of the data as the test data.

# %% [markdown]
# ## Random forest Classifier for the Customer Churn Data

# %%
import time
import sys
from sklearn.ensemble import RandomForestClassifier
start_time_randomforest=time.time()
rnd_clf=RandomForestClassifier(n_estimators=6000,max_leaf_nodes=10,n_jobs=-1,random_state=42)
rnd_clf.fit(X1_train,y1_train)
y1_pred_rf=rnd_clf.predict(X1_test)
time_needed_randomforest=time.time()-start_time_randomforest
space_needed_randomforest=sys.getsizeof(rnd_clf)
print("Time needed(time complexity) to train the classifier",time_needed_randomforest)
print("space used to train the classifier",space_needed_randomforest)
# Out:
# Time needed(time complexity) to train the classifier 23.21956968307495
# space used to train the classifier 56

# %% [raw]
# In the above kernel we have trained the randomforest classifier using our modified data1.We have used 6000 different
# decision trees and in each decision tree we have allowed maximum 10 leaf nodes, which probably reduce the danger of overfitting
# we have also computed how much time(for both training and prediction) and space is used to train the classifier using data1.

# %% [markdown]
# ## Adaboost  classifier for the Customer Churn Data

# %%
from sklearn.ensemble import AdaBoostClassifier
start_time_adaboost=time.time()
adaboost_clf=AdaBoostClassifier(n_estimators=500,random_state=42)
adaboost_clf.fit(X1_train,y1_train)
y1_pred_adaboost=adaboost_clf.predict(X1_test)
time_needed_adaboost=time.time()-start_time_adaboost
space_needed_adaboost=sys.getsizeof(adaboost_clf)
print("Time needed for the Adaboost classifier",time_needed_adaboost)
print("Space needed for the adaboost classifier",space_needed_adaboost)
# Out:
# Time needed for the Adaboost classifier 3.4428281784057617
# Space needed for the adaboost classifier 56

# %% [raw]
# Here we have uses Adaboost classifier to predict Churn of a customer using the given churnn data set.
# previously we have splitted the whole data set into training and test data set seperately.
# we have used 500 weak classifier in this Adaboost model.
# we have also computed how much time(for training and predict) and space is required to train the classifier.

# %% [markdown]
# ## Accuracy For Both The Classifiers

# %%
from sklearn.metrics import accuracy_score
adaboost_accuracy=accuracy_score(y1_test,y1_pred_adaboost)
random_forest_accuracy=accuracy_score(y1_test,y1_pred_rf)

# %%
print("Accuracy on Adaboost Classifier:", adaboost_accuracy)
print("Accuracy on Random Forest Classifier:",random_forest_accuracy)
# Out:
# Accuracy on Adaboost Classifier: 0.54
# Accuracy on Random Forest Classifier: 0.56

# %% [markdown]
# ## Conclusion

# %% [raw]
# Both the Random-forest and the adaboost classifier used the same amount of space to get trained.
# But there is a significant time diffrence between them, while the random-forest classifier takes 23 sec(approx) ,the adaboost classifiertake 3 sec(approx), to get trained and predict the same data. Accuracy for both of the classifier is not too good. They arejust above the average. For the Adaoost classifier the accuracy is 54 percent and for the random_forest classifier the    accuracy is 56 percent.

# %% [markdown]
# # Task 2: Supermarket Sales Data

# %% [markdown]
# ## The data set

# %%
data2=pd.read_csv("supermarket-sales-data .csv")
data2
# Out:
#        InvoiceID Branch CustomerType  Gender             ProductType  \
# 0    750-67-8428      A       Member  Female       Health and beauty
# 1    226-31-3081      C       Normal  Female  Electronic accessories
# 2    631-41-3108      A       Normal    Male      Home and lifestyle
# 3    123-19-1176      A       Member    Male       Health and beauty
# 4    373-73-7910      A       Normal    Male       Sports and travel
# ..           ...    ...          ...     ...                     ...
# 995  233-67-5758      C       Normal    Male       Health and beauty
# 996  303-96-2227      B       Normal  Female      Home and lifestyle
# 997  727-02-1313      A       Member    Male      Food and beverages
# 998  347-56-2442      A       Normal    Male      Home and lifestyle
# 999  849-09-3807      A       Member  Female     Fashion accessories
#
#      UnitPrice  Quantity      Tax      Total  PaymentType  Rating
# 0        74.69         7  26.1415   548.9715          UPI     9.1
# ...

# %% [raw]
# Clearly we can see above the Super-Market-sales data set as a panda data-frame. The data set have 11 colums. Categorical and
# numerical both of the column types are there.There is also a identifier column for the data set, namely the InvoiceId column.
# It have 1000 rows and 11 columns(each column represents a different attribute).

# %%
from sklearn.preprocessing import LabelEncoder

data2 = pd.read_csv("supermarket-sales-data .csv")
data2=data2.drop(columns=["InvoiceID"])

categorical_cols = ["Branch","CustomerType","ProductType","PaymentType"]

label_encoder = LabelEncoder()
for col in categorical_cols:
    data2[col] = label_encoder.fit_transform(data2[col])

# %% [markdown]
# ## Modified Data

# %%
data2
# Out:
#      Branch  CustomerType  Gender  ProductType  UnitPrice  Quantity      Tax  \
# 0         0             0  Female            3      74.69         7  26.1415
# 1         2             1  Female            0      15.28         5   3.8200
# 2         0             1    Male            4      46.33         7  16.2155
# 3         0             0    Male            3      58.22         8  23.2880
# 4         0             1    Male            5      86.31         7  30.2085
# ..      ...           ...     ...          ...        ...       ...      ...
# 995       2             1    Male            3      40.35         1   2.0175
# 996       1             1  Female            4      97.38        10  48.6900
# 997       0             0    Male            2      31.84         1   1.5920
# 998       0             1    Male            4      65.82         1   3.2910
# 999       0             0  Female            1      88.34         7  30.9190
#
#          Total  PaymentType  Rating
# ...

# %% [raw]
# Here we can see the modified data set. We have made some changes to train machine learning models with the data set.
# Firstly we have deleted the "InvoiceID" column from the data set, which is an unique identifier of each row of the data set.
# So it is not a very effective column to identify gender of any person from the data set(as the information gain ratio will be low).
# After that using label-encoding we have turned all the categorical column into a numerical column except the gender column.
# which is our target variable for the first classification.

# %% [markdown]
# ## Decision-Tree classifier to predict Gender

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split


X2 = data2.drop(columns=["Gender"])
y2 = data2["Gender"] 


X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

start_time=time.time()
dt_classifier = DecisionTreeClassifier(max_leaf_nodes=10)
dt_classifier.fit(X2_train, y2_train)
dt_pred = dt_classifier.predict(X2_test)
time_decision_tree=time.time()-start_time
space_needed_decisiontree=sys.getsizeof(dt_classifier)
print("Time required for the decision-tree classifier",time_decision_tree)
print("Space required for the decision tree classifier",space_needed_decisiontree)
# Out:
# Time required for the decision-tree classifier 0.019819974899291992
# Space required for the decision tree classifier 56

# %% [markdown]
# # Random-Forest Classifier to Predict Gender

# %%
rf_classifier2 = RandomForestClassifier(n_estimators=6000,max_leaf_nodes=10,n_jobs=-1,random_state=42)
start_time=time.time()
rf_classifier2.fit(X2_train, y2_train)
rf2_pred=rf_classifier2.predict(X2_test)
time_rf2=time.time()-start_time
space_needed_rf2=sys.getsizeof(rf_classifier2)
print("Time required for the random forest classifier",time_rf2)
print("Space required for the random forest classifier",space_needed_rf2)
# Out:
# Time required for the random forest classifier 21.253355741500854
# Space required for the random forest classifier 56

# %% [markdown]
# # Accuracy of both the Classifier

# %%
rf2_accuracy = accuracy_score(y2_test, rf2_pred)
print("Random Forest Classifier Accuracy:", rf2_accuracy)
dt_accuracy = accuracy_score(y2_test, dt_pred)
print("Decision Tree Classifier Accuracy:", dt_accuracy)
# Out:
# Random Forest Classifier Accuracy: 0.525
# Decision Tree Classifier Accuracy: 0.5

# %% [markdown]
# # Overall Conclusion

# %% [raw]
# In the above you vcan see that we have split the data into training set and test set and using the training part of the data we ,
# have built two models.One of them is random forest classifier and another is decision tree classifier.
# our training data is 80 percent of the whole data which is chosen randomly by scikit learn with the help of the function
# train_test_split.
# while training the decision tree classifier we have taken number of max leaf nodes 10 to escape from the danger of overfitting.
# while training the random forest classifier we have taken 6000 different decision trees so that the problem of variance go,as much
# as we can. Every decision tree in the random forest can have max leaf nodes 10(to reduce the danger of over-fitting).And while traing
# the random forest classifier we have use all the available cores of cpu so that time complexity can be reduced.
# Now space taken by both the models to be trained are same. But there is a significant difference of time to be trained of both the
# classifier. In the case of the first classifier the time taken by the first classifier(the decision tree classifier) is approx
# 0.01 second , while the second classifier takes 21.253 second(it is because we train many decision tree).
#
#
# Both the classifier has have almost same accuracy, the random forest classifier predict the output with the accuracy of 52 percent,
# while the decision tree classifier do it with accuracy 50 percent. Which is acceptable ,as we wxpect the variance in the random
# forest classifier to be less than a single decision tree ,and so it can capture the distribution of thr main data better than
# a single decision tree and the accuracy will be increased for that.

# %% [markdown]
# # Rating Prediction From The Supermarket-sales data set

# %%
data3=pd.read_csv("supermarket-sales-data .csv")
data3
# Out:
#        InvoiceID Branch CustomerType  Gender             ProductType  \
# 0    750-67-8428      A       Member  Female       Health and beauty
# 1    226-31-3081      C       Normal  Female  Electronic accessories
# 2    631-41-3108      A       Normal    Male      Home and lifestyle
# 3    123-19-1176      A       Member    Male       Health and beauty
# 4    373-73-7910      A       Normal    Male       Sports and travel
# ..           ...    ...          ...     ...                     ...
# 995  233-67-5758      C       Normal    Male       Health and beauty
# 996  303-96-2227      B       Normal  Female      Home and lifestyle
# 997  727-02-1313      A       Member    Male      Food and beverages
# 998  347-56-2442      A       Normal    Male      Home and lifestyle
# 999  849-09-3807      A       Member  Female     Fashion accessories
#
#      UnitPrice  Quantity      Tax      Total  PaymentType  Rating
# 0        74.69         7  26.1415   548.9715          UPI     9.1
# ...

# %%
data3=data3.drop(columns=["InvoiceID"])

categorical_cols = ["Branch","CustomerType","ProductType","PaymentType","Gender"]

label_encoder = LabelEncoder()
for col in categorical_cols:
    data3[col] = label_encoder.fit_transform(data3[col])

# %% [markdown]
# # Modified data3

# %%
data3
# Out:
#      Branch  CustomerType  Gender  ProductType  UnitPrice  Quantity      Tax  \
# 0         0             0       0            3      74.69         7  26.1415
# 1         2             1       0            0      15.28         5   3.8200
# 2         0             1       1            4      46.33         7  16.2155
# 3         0             0       1            3      58.22         8  23.2880
# 4         0             1       1            5      86.31         7  30.2085
# ..      ...           ...     ...          ...        ...       ...      ...
# 995       2             1       1            3      40.35         1   2.0175
# 996       1             1       0            4      97.38        10  48.6900
# 997       0             0       1            2      31.84         1   1.5920
# 998       0             1       1            4      65.82         1   3.2910
# 999       0             0       0            1      88.34         7  30.9190
#
#          Total  PaymentType  Rating
# ...

# %% [raw]
# Here above we have done preprocessing of the Super Market data set again as above.  we have done all the work same but here
# we have also turned the categorical Gender attributr to a numerical atrribute .As we are going to predict Rating
# with the help of this modified data.

# %% [markdown]
# # Linear-Regression Model to Predict Rating

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
X3=data3.drop(columns=['Rating'])
y3=data3['Rating']
X3_train,X3_test,y3_train,y3_test=train_test_split(X3,y3,test_size=0.2,random_state=42)
lin_reg_model=LinearRegression()
start_time_linearregression=time.time()
lin_reg_model.fit(X3_train,y3_train)
y3_pred_linear_reg=lin_reg_model.predict(X3_test)
linear_reg_mse=mean_squared_error(y3_test,y3_pred_linear_reg)
time_linearregression=time.time()-start_time_linearregression
space_linearregression=sys.getsizeof(lin_reg_model)
print("Time required to train the linear regression model",time_linearregression)
print("Space required for the linear_regression model",space_linearregression)
# Out:
# Time required to train the linear regression model 0.0756082534790039
# Space required for the linear_regression model 56

# %% [markdown]
# # Decision-Tree regressor to predict Rating

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree_model2=DecisionTreeRegressor()
start_time_decisiontree2=time.time()
decision_tree_model2.fit(X3_train,y3_train)
y3_pred_decision_tree2=decision_tree_model2.predict(X3_test)
time_decisiontree2=time.time()-start_time_decisiontree2
space_decisiontree2=sys.getsizeof(decision_tree_model2)
print("Time required for the decision-tree model",time_decisiontree2)
print("Space required for the decision-tree model",space_decisiontree2)
# Out:
# Time required for the decision-tree model 0.037895917892456055
# Space required for the decision-tree model 56

# %% [markdown]
# # Acuuracy of both the Classifiers

# %%
decision_tree2_mse=mean_squared_error(y3_test,y3_pred_decision_tree2)
linear_reg_mse=mean_squared_error(y3_test,y3_pred_linear_reg)
print("Mean squared error of the decision tree regressor(CART) is:",decision_tree2_mse)
print("Mean Squared error of the linear regressor is:",linear_reg_mse)
# Out:
# Mean squared error of the decision tree regressor(CART) is: 6.59595
# Mean Squared error of the linear regressor is: 3.1170468475043425

# %% [markdown]
# # Overall Conclusion

# %% [raw]
# In the above we have developed two regression model to predict the rating of the super-market data set.
# one of them is decision-tree regressor and the another one is linear-regressio model.
# As before we have splitted the Super-Market data set randomly.We have used 80 percent of the data for training of both models and
# the rest 20 percent we have used to measure the accuracy.
# Both the models have occupied same amount of space to be trained, and there is no significant time diffrence between the two models
# to be trained. The linear regresion model takes 0.07(approx) sec to be trained , while the decision tree regressor takes 0.03
# sec(approx).
# There is also a noticable difference between the acuuracy if both the classifiers.(Note:Here we have used mean-squred error
# to comare the accuracy of the two models, as they are regression models , so mean squared error is a good estimate to compare the
# two models, as it estimates how the overall observable output deviates from our predicted output).
# You ca see that for the decision tree and for the linear regression model the mean squared errors are 6.6(approx) ad 3.12(approx)
# respectively.
# So we can say that the CART model(the decisio tree model) predicts the rating more accurately tha the linear regressor model.
